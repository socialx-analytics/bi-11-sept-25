# %% [markdown]
# <a href="https://colab.research.google.com/github/socialx-analytics/bi-11-sept-25/blob/main/003_yahoo_finance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install & import library
# !pip -q install yfinance

import yfinance as yf
import pandas as pd
from google.colab import files

# %%
# Set simbol saham/indeks
symbol = "^JKLQ45"   # LQ45 Index
symbol
# Out:
# '^JKLQ45'

# %%
# Ambil data harga (default: periode max, interval 1 hari)
df = yf.download(symbol, period="max", interval="1d")
df
# Out:
# /tmp/ipython-input-1010779298.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, period="max", interval="1d")
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open      Volume
# Ticker         ^JKLQ45     ^JKLQ45     ^JKLQ45     ^JKLQ45     ^JKLQ45
# Date
# 1997-02-24  147.070007  147.779999  146.740005  147.220001           0
# 1997-02-25  147.500000  147.559998  146.970001  147.029999           0
# 1997-02-26  150.199997  150.199997  147.470001  147.500000           0
# 1997-02-27  149.419998  151.350006  148.869995  150.199997           0
# 1997-02-28  148.179993  149.419998  147.509995  149.210007           0
# ...                ...         ...         ...         ...         ...
# 2025-09-04  799.799988  801.109985  795.409973  798.270020  3561400000
# 2025-09-08  783.590027  810.409973  783.590027  810.330017  4950000000
# ...

# %%
# Simpan ke CSV & auto-download
filename = f"{symbol.replace('^','')}.csv"
df.to_csv(filename)
files.download(filename)
